# %% [markdown]
# # Módulo 10 tarefa 03
# Considere a mesma base de dados utilizada na tarefa 1 ```previsao_de_renda.csv```.

# %% [markdown]
# 1) Construa um gráfico de barras para avaliar a distribuição das variáveis qualitativas no tempo. Você acha que houve alguma alteração importante a ser investigada?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.formula.api import ols
import seaborn as sns
import numpy as np

df = pd.read_csv('previsao_de_renda.csv')

# %%
# Configurar o estilo do seaborn
sns.set(style="whitegrid")

# Criar o gráfico de barras para 'sexo' ao longo do tempo
plt.figure(figsize=(12, 8))
barplot_sexo = sns.countplot(
    x='data_ref',
    hue='sexo',
    data=df,
)

# Adicionar rótulos e título
plt.title('Distribuição de Sexo ao Longo do Tempo', fontsize=16)
plt.xlabel('Data de Referência', fontsize=14)
plt.ylabel('Contagem', fontsize=14)

# Rotacionar rótulos do eixo x para melhor legibilidade
plt.xticks(rotation=45, ha='right')

# Adicionar legenda
plt.legend(title='Sexo', loc='upper right')

# Ajustar o layout
plt.tight_layout()

# Mostrar o gráfico
plt.show()

# %%
# Configurar o estilo do seaborn
sns.set(style="whitegrid")

# Criar o gráfico de barras para 'posse_de_veiculo' ao longo do tempo
plt.figure(figsize=(12, 8))
barplot_posse_veiculo = sns.countplot(
    x='data_ref',
    hue='posse_de_veiculo',
    data=df,
)

# Adicionar rótulos e título
plt.title('Distribuição de Posse de Veículo ao Longo do Tempo', fontsize=16)
plt.xlabel('Data de Referência', fontsize=14)
plt.ylabel('Contagem', fontsize=14)

# Rotacionar rótulos do eixo x para melhor legibilidade
plt.xticks(rotation=45, ha='right')

# Adicionar legenda
plt.legend(title='posse_de_veiculo', loc='upper right')

# Ajustar o layout
plt.tight_layout()

# Mostrar o gráfico
plt.show()

# %%
# Configurar o estilo do seaborn
sns.set(style="whitegrid")

# Criar o gráfico de barras para 'posse_de_imovel' ao longo do tempo
plt.figure(figsize=(12, 8))
barplot_posse_de_imovel = sns.countplot(
    x='data_ref',
    hue='posse_de_imovel',
    data=df,
)

# Adicionar rótulos e título
plt.title('Distribuição de Posse de Imóvel ao Longo do Tempo', fontsize=16)
plt.xlabel('Data de Referência', fontsize=14)
plt.ylabel('Contagem', fontsize=14)

# Rotacionar rótulos do eixo x para melhor legibilidade
plt.xticks(rotation=45, ha='right')

# Adicionar legenda
plt.legend(title='posse_de_imovel', loc='upper right')

# Ajustar o layout
plt.tight_layout()

# Mostrar o gráfico
plt.show()

# %%
# Configurar o estilo do seaborn
sns.set(style="whitegrid")

# Criar o gráfico de barras para 'tipo_renda' ao longo do tempo
plt.figure(figsize=(12, 8))
barplot_tipo_de_renda = sns.countplot(
    x='data_ref',
    hue='tipo_renda',
    data=df,
)

# Adicionar rótulos e título
plt.title('Distribuição de Tipo de Renda ao Longo do Tempo', fontsize=16)
plt.xlabel('Data de Referência', fontsize=14)
plt.ylabel('Contagem', fontsize=14)

# Rotacionar rótulos do eixo x para melhor legibilidade
plt.xticks(rotation=45, ha='right')

# Adicionar legenda
plt.legend(title='tipo_renda', loc='upper right')

# Ajustar o layout
plt.tight_layout()

# Mostrar o gráfico
plt.show()

# %%
# Configurar o estilo do seaborn
sns.set(style="whitegrid")

# Criar o gráfico de barras para 'educacao' ao longo do tempo
plt.figure(figsize=(12, 8))
barplot_educacao = sns.countplot(
    x='data_ref',
    hue='educacao',
    data=df,
)

# Adicionar rótulos e título
plt.title('Distribuição de Educação ao Longo do Tempo', fontsize=16)
plt.xlabel('Data de Referência', fontsize=14)
plt.ylabel('Contagem', fontsize=14)

# Rotacionar rótulos do eixo x para melhor legibilidade
plt.xticks(rotation=45, ha='right')

# Adicionar legenda
plt.legend(title='educacao', loc='upper right')

# Ajustar o layout
plt.tight_layout()

# Mostrar o gráfico
plt.show()

# %%
# Configurar o estilo do seaborn
sns.set(style="whitegrid")

# Criar o gráfico de barras para 'estado_civil' ao longo do tempo
plt.figure(figsize=(12, 8))
barplot_educacao = sns.countplot(
    x='data_ref',
    hue='estado_civil',
    data=df,
)

# Adicionar rótulos e título
plt.title('Distribuição de Estado Civil ao Longo do Tempo', fontsize=16)
plt.xlabel('Data de Referência', fontsize=14)
plt.ylabel('Contagem', fontsize=14)

# Rotacionar rótulos do eixo x para melhor legibilidade
plt.xticks(rotation=45, ha='right')

# Adicionar legenda
plt.legend(title='estado_civil', loc='upper right')

# Ajustar o layout
plt.tight_layout()

# Mostrar o gráfico
plt.show()

# %%
# Configurar o estilo do seaborn
sns.set(style="whitegrid")

# Criar o gráfico de barras para 'tipo_residencia' ao longo do tempo
plt.figure(figsize=(12, 8))
barplot_educacao = sns.countplot(
    x='data_ref',
    hue='tipo_residencia',
    data=df,
)

# Adicionar rótulos e título
plt.title('Distribuição de Tipo de Residência ao Longo do Tempo', fontsize=16)
plt.xlabel('Data de Referência', fontsize=14)
plt.ylabel('Contagem', fontsize=14)

# Rotacionar rótulos do eixo x para melhor legibilidade
plt.xticks(rotation=45, ha='right')

# Adicionar legenda
plt.legend(title='tipo_residencia', loc='upper right')

# Ajustar o layout
plt.tight_layout()

# Mostrar o gráfico
plt.show()

# %%
# Configurar o estilo do seaborn
sns.set(style="whitegrid")

# Criar o gráfico de barras para  'mau' ao longo do tempo
plt.figure(figsize=(12, 8))
barplot_educacao = sns.countplot(
    x='data_ref',
    hue= 'mau',
    data=df,
)

# Adicionar rótulos e título
plt.title('Distribuição de Mau ao Longo do Tempo', fontsize=16)
plt.xlabel('Data de Referência', fontsize=14)
plt.ylabel('Contagem', fontsize=14)

# Rotacionar rótulos do eixo x para melhor legibilidade
plt.xticks(rotation=45, ha='right')

# Adicionar legenda
plt.legend(title= 'mau', loc='upper right')

# Ajustar o layout
plt.tight_layout()

# Mostrar o gráfico
plt.show()

# %% [markdown]
# Ao analisar os gráficos, verificou-se a seguinte alteração significativa:
#
# Identificou-se uma mudança substancial na distribuição educacional dos indivíduos ao longo do tempo.
# Houve uma queda significativa no número de indivíduos com educação de nível secundário e um aumento correspondente na proporção de pessoas com educação de nível superior.

# %% [markdown]
# 2) Para cada variável qualitativa, construa um gráfico mostrando as médias de cada nível da variável no tempo e avalie a estabilidade. Houve alguma alteração importante? Você acha que se pode utilizar essas variáveis em uma modelagem?

# %%
# Configurar o estilo do seaborn
sns.set(style="whitegrid")

# Criar o gráfico de linha para as médias de 'educação' ao longo do tempo
plt.figure(figsize=(12, 8))
lineplot_educacao = sns.lineplot(
    x='data_ref',
    y='educacao',
    hue='educacao',
    estimator='mean',  
    err_style=None, 
    data=df,
)

# Adicionar rótulos e título
plt.title('Médias de Educação ao Longo do Tempo', fontsize=16)
plt.xlabel('Data de Referência', fontsize=14)
plt.ylabel('Média de Educação', fontsize=14)

# Rotacionar rótulos do eixo x para melhor legibilidade
plt.xticks(rotation=45, ha='right')

# Ajustar o layout
plt.tight_layout()

# Mostrar o gráfico
plt.show()

# %%
# Configurar o estilo do seaborn
sns.set(style="whitegrid")

# Criar o gráfico de linha para as médias de 'sexo' ao longo do tempo
plt.figure(figsize=(12, 8))
lineplot_sexo = sns.lineplot(
    x='data_ref',
    y='sexo',
    hue='sexo',
    estimator='mean',  
    err_style=None, 
    data=df,
)

# Adicionar rótulos e título
plt.title('Médias de Sexo ao Longo do Tempo', fontsize=16)
plt.xlabel('Data de Referência', fontsize=14)
plt.ylabel('Média de Sexo', fontsize=14)

# Rotacionar rótulos do eixo x para melhor legibilidade
plt.xticks(rotation=45, ha='right')

# Ajustar o layout
plt.tight_layout()

# Mostrar o gráfico
plt.show()

# %%
# Configurar o estilo do seaborn
sns.set(style="whitegrid")

# Criar o gráfico de linha para as médias de 'posse_de_veiculo' ao longo do tempo
plt.figure(figsize=(12, 8))
lineplot_posse_de_veiculo = sns.lineplot(
    x='data_ref',
    y='posse_de_veiculo',
    hue='posse_de_veiculo',
    estimator='mean',  
    err_style=None,  
    data=df,
)

# Adicionar rótulos e título
plt.title('Médias de Posse de Veículo ao Longo do Tempo', fontsize=16)
plt.xlabel('Data de Referência', fontsize=14)
plt.ylabel('Média de Posse de Veícuolo', fontsize=14)

# Rotacionar rótulos do eixo x para melhor legibilidade
plt.xticks(rotation=45, ha='right')

# Ajustar o layout
plt.tight_layout()

# Mostrar o gráfico
plt.show()

# %%
# Configurar o estilo do seaborn
sns.set(style="whitegrid")

# Criar o gráfico de linha para as médias de 'posse_de_imovel' ao longo do tempo
plt.figure(figsize=(12, 8))
lineplot_posse_de_veiculo = sns.lineplot(
    x='data_ref',
    y='posse_de_imovel',
    hue='posse_de_imovel',
    estimator='mean',  
    err_style=None,  
    data=df,
)

# Adicionar rótulos e título
plt.title('Médias de Posse de Imovel ao Longo do Tempo', fontsize=16)
plt.xlabel('Data de Referência', fontsize=14)
plt.ylabel('Média de Posse de Imóvel', fontsize=14)

# Rotacionar rótulos do eixo x para melhor legibilidade
plt.xticks(rotation=45, ha='right')

# Ajustar o layout
plt.tight_layout()

# Mostrar o gráfico
plt.show()

# %%
# Configurar o estilo do seaborn
sns.set(style="whitegrid")

# Criar o gráfico de linha para as médias de 'tipo_renda' ao longo do tempo
plt.figure(figsize=(12, 8))
lineplot_posse_de_veiculo = sns.lineplot(
    x='data_ref',
    y='tipo_renda',
    hue='tipo_renda',
    estimator='mean',  
    err_style=None,  
    data=df,
)

# Adicionar rótulos e título
plt.title('Médias de Tipo de Renda ao Longo do Tempo', fontsize=16)
plt.xlabel('Data de Referência', fontsize=14)
plt.ylabel('Média de Tipo de Renda', fontsize=14)

# Rotacionar rótulos do eixo x para melhor legibilidade
plt.xticks(rotation=45, ha='right')

# Ajustar o layout
plt.tight_layout()

# Mostrar o gráfico
plt.show()

# %%
# Configurar o estilo do seaborn
sns.set(style="whitegrid")

# Criar o gráfico de linha para as médias de 'tipo_residencia' ao longo do tempo
plt.figure(figsize=(12, 8))
lineplot_posse_de_veiculo = sns.lineplot(
    x='data_ref',
    y='tipo_residencia',
    hue='tipo_residencia',
    estimator='mean',  
    err_style=None,  
    data=df,
)

# Adicionar rótulos e título
plt.title('Médias de Tipo de Residência ao Longo do Tempo', fontsize=16)
plt.xlabel('Data de Referência', fontsize=14)
plt.ylabel('Média de Tipo de Residência', fontsize=14)

# Rotacionar rótulos do eixo x para melhor legibilidade
plt.xticks(rotation=45, ha='right')

# Ajustar o layout
plt.tight_layout()

# Mostrar o gráfico
plt.show()

# %% [markdown]
# A partir da análise visual, foi observada grande estabilidade em todas as médias ao longo do tempo nos gráficos de linha, isso é um indicativo positivo para a inclusão dessas variáveis em modelos estatísticos. A estabilidade nas médias sugere que essas variáveis não estão sujeitas a variações significativas ao longo do tempo, o que pode fortalecer sua utilidade como preditores em modelos estatísticos.
# No entanto, devido a relevância teórica da variável 'Educação', à depender da  pergunta de pesquisa e ao contexto do estudo seria apropriada para a modelação.
